# %%
import pandas as pd

# %%
data_prod = pd.read_csv(
    filepath_or_buffer=r"/home/pdconte/Desktop/vm_app/data/well_prod_data.csv"
)

# %%
data_prod.columns
# Out:
# Index(['company_id', 'year', 'month', 'well_id', 'oil_prod_m3', 'gas_prod_km3',
#        'water_prod_m3', 'water_inj_m3', 'well_type', 'entry_date', 'company',
#        'well_name', 'depth_m', 'field', 'Xcoor', 'Ycoor', 'type', 'subtype',
#        'month_count', 'oil_cum_m3', 'gas_cum_km3', 'water_prod_cum_m3',
#        'water_inj_cum_m3'],
#       dtype='object')

# %%
data_prod
# Out:
#        company_id  year  month  well_id  oil_prod_m3  gas_prod_km3  \
# 0             PEL  2006      2     3640        0.000         0.000
# 1             PEL  2006      3     3640       30.808         1.731
# 2             PEL  2006      4     3640       76.609         3.713
# 3             PEL  2006      5     3640       63.273         4.202
# 4             PEL  2006      6     3640       55.043         4.373
# ...           ...   ...    ...      ...          ...           ...
# 187417        YPF  2025     10   166894       15.460         4.550
# 187418        YPF  2025     10   166895      446.870       115.200
# 187419        YPF  2025     10   166896      136.380        15.990
# 187420        SHE  2025     10   166897     3556.790      4297.700
# 187421        SHE  2025     10   166898     2253.880      3781.020
#
#         water_prod_m3  water_inj_m3    well_type                  entry_date  \
# 0               0.000           0.0  Petrolífero  2006-11-22 11:55:24.382903
# ...

# %%
data_prod.groupby("company_id")["oil_prod_m3"].sum()
# Out:
# company_id
# ACO     6.263136e+02
# AESA    1.610000e+02
# AME     3.291186e+04
# APEA    0.000000e+00
# APGA    0.000000e+00
# APS     2.096006e+05
# BEN     8.567080e+02
# CHE     1.261014e+06
# CNA     7.241000e+02
# EMEA    2.054824e+06
# ENE1    0.000000e+00
# FXS     0.000000e+00
# GGO     9.817300e+02
# GPNE    6.177500e+02
# GREC    4.109248e+03
# KILW    1.802973e+06
# MAD     6.218713e+01
# MSA     1.903358e+04
# OGDV    5.514717e+05
# OILS    2.165687e+02
# PAE     2.192067e+05
# PAL     6.168628e+06
# PAM     4.782865e+05
# PBE     1.214522e+04
# PCN     4.997769e+05
# PCR     2.107993e+04
# PEL     9.290848e+04
# PES     1.912949e+03
# PLU     3.630391e+06
# PTRE    2.217791e+05
# ROC     4.329205e+03
# SHE     8.259505e+06
# TAU     1.317071e+06
# TPT     3.314133e+06
# VIS     2.353554e+06
# VMI     2.341959e+04
# VNO     2.692370e+03
# VOG     9.934623e+04
# VST     1.069122e+07
# WDA     1.403597e+05
# WIN     1.008769e+05
# YPF     6.550588e+07
# ...
